# %% [markdown]
# # Colab setup — adversarial_classifier
#
# This notebook helps you run the project on Google Colab (use Colab Pro for faster/priority GPUs).

# %% [markdown]
# **Before running:** Runtime -> Change runtime type -> Hardware accelerator -> `GPU`.
# Sign in with your Google account and mount Drive if you want persistent storage.

# %%
# Mount Google Drive (optional)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone this repo (replace URL with your own if needed) and install requirements
# !git clone https://github.com/nishadw/adversarial_classifier.git repo || true
# !pip install -r repo/requirements.txt

# %%
# Quick run example (adjust path/args as needed)
# !python repo/src/adversarial_classifier/train.py --epochs 1 --device cuda
